# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")
# Out:
# C:\Users\Ut Luom\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (35,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Ut Luom\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (34,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_train.head()
# Out:
#    id  label                   Field_1               Field_2  Field_3 Field_4  \
# 0   0      1  2019-07-24T03:39:02.854Z  2019-07-31T20:10:02Z      1.0      GH
# 1   1      0                       NaN                   NaN      NaN     NaN
# 2   2      0  2019-01-17T07:15:26.367Z  2019-01-17T07:17:45Z      2.0      T1
# 3   3      0                       NaN                   NaN      NaN     NaN
# 4   4      1                       NaN                   NaN      NaN     NaN
#
#       Field_5     Field_6     Field_7     Field_8  ... partner5_H  partner5_K  \
# 0  2018-12-27  2018-12-27  2019-01-01  2019-07-31  ...        0.0         0.0
# 1         NaN         NaN         NaN         NaN  ...        0.0         0.0
# 2  2019-01-17  2019-01-17  2019-01-01  2019-12-31  ...        0.0         0.0
# 3         NaN         NaN         NaN         NaN  ...        NaN         NaN
# 4         NaN         NaN         NaN         NaN  ...        NaN         NaN
#
#   partner5_L brief  num_of_phone  Field_78   Field_79  Field_80  Field_81  \
# 0        0.0   cb1           1.0       NaN        NaN       NaN       NaN
# 1        0.0     4           1.0       NaN        NaN       NaN       NaN
# 2        0.0     1           1.0      33.0  10.769445  6.466667       0.0
# 3        NaN     1           1.0      33.0  10.769445  6.466667       0.0
# 4        NaN     1           1.0      33.0  10.769445  6.466667       0.0
#
#   Field_82
# 0        1
# 1        1
# 2        2
# 3        3
# 4        3
#
# [5 rows x 195 columns]

# %%
df_train.isnull().sum()
# Out:
# id              0
# label           0
# Field_1     27466
# Field_2     27466
# Field_3     27466
#             ...
# Field_78    16633
# Field_79    25248
# Field_80    16710
# Field_81    17049
# Field_82        0
# Length: 195, dtype: int64

# %%
df_train.shape
# Out:
# (53030, 195)

# %%
df_train.columns
# Out:
# Index(['id', 'label', 'Field_1', 'Field_2', 'Field_3', 'Field_4', 'Field_5',
#        'Field_6', 'Field_7', 'Field_8',
#        ...
#        'partner5_H', 'partner5_K', 'partner5_L', 'brief', 'num_of_phone',
#        'Field_78', 'Field_79', 'Field_80', 'Field_81', 'Field_82'],
#       dtype='object', length=195)

# %% [markdown]
# ### Clean Data

# %% [markdown]
# ##### Xử lí số liệu

# %% [markdown]
# Label

# %%
df_train["label"].value_counts()
# Out:
# 0    36234
# 1    16796
# Name: label, dtype: int64

# %%
df_train["label"].astype(int).plot.hist();

# %% [markdown]
# Nhận xét:
#     - Mất cân bằng: Có nhiều khoản vay trả đúng hạn hơn so với những khoản vay không được hoàn trả

# %% [markdown]
# ### Xem các giá trị còn thiếu và phần trăm

# %% [markdown]
# xem theo cột...

# %%
# Hàm tính tổng các giá trị còn thiếu
def missing_values(df):
    mis_val = df.isnull().sum() #tổng các giá trị còn thiếu
    mis_val_per = 100 * df.isnull().sum()/len(df) #Phần trăm các giá trị còn thiếu
    mis_val_table = pd.concat([mis_val, mis_val_per], axis=1) #Tạo thành bảng để thể hiện 2 giá trị trên
    mis_val_table_rename = mis_val_table.rename(
    columns = {0: "Thiếu", 1 : "Chiếm %"})
    #Sắp xếp bảng theo tỉ lệ phần trăm giảm dần
    mis_val_table_rename = mis_val_table_rename[mis_val_table_rename.iloc[:, 1] != 0].sort_values("Chiếm %", ascending=False).round(1)
    print("Có tất cả " + str(df.shape[1]) + " cột.\n"
          "Có tất cả " + str(mis_val_table_rename.shape[0]) + " cột bị thiếu data")
    return mis_val_table_rename

# %%
missing = missing_values(df_train)
missing.head(20)
# Out:
# Có tất cả 195 cột.
# Có tất cả 192 cột bị thiếu data
#                         Thiếu  Chiếm %
# Field_35                46198     87.1
# Field_12                45650     86.1
# Field_11                45616     86.0
# Field_18                44643     84.2
# maCv                    43882     82.7
# homeTownCity            40676     76.7
# homeTownCountry         40676     76.7
# homeTownName            40676     76.7
# homeTownState           40676     76.7
# currentLocationState    39522     74.5
# currentLocationCity     39521     74.5
# currentLocationCountry  39521     74.5
# currentLocationName     39521     74.5
# Field_54                38574     72.7
# Field_15                37322     70.4
# Field_68                33045     62.3
# Field_40                32415     61.1
# Field_74                32372     61.0
# topFriends              32364     61.0
# Field_38                32326     61.0

# %%
#Số lượng từng loại dữ liệu có trong cột
df_train.dtypes.value_counts()
# Out:
# float64    133
# object      59
# int64        3
# dtype: int64

# %%
#Số lượng object(categorical) có trong mỗi cột
df_train.select_dtypes("object").apply(pd.Series.nunique, axis=0)
# Out:
# Field_1                   21506
# Field_2                   18667
# Field_4                       2
# Field_5                    1901
# Field_6                    1870
# Field_7                    1199
# Field_8                    1392
# Field_9                    1929
# Field_11                    836
# Field_12                      7
# Field_15                   1539
# Field_18                   6587
# Field_25                   1613
# Field_32                   1527
# Field_33                   1753
# Field_34                   2635
# Field_35                    632
# gioiTinh                      2
# diaChi                    21057
# Field_36                     34
# Field_38                      6
# Field_40                    541
# Field_43                   3605
# Field_44                   9901
# Field_45                  10957
# Field_46                  14311
# Field_47                      5
# Field_48                  12650
# Field_49                  12818
# Field_54                     44
# Field_55                    220
# Field_56                   1345
# Field_61                     35
# Field_62                      6
# Field_65                     10
# Field_66                      8
# Field_68                  10944
# maCv                       3589
# info_social_sex               2
# data.basic_info.locale       24
# currentLocationCity         876
# currentLocationCountry       48
# currentLocationName        1087
# currentLocationState        201
# homeTownCity                886
# homeTownCountry              38
# homeTownName               1133
# homeTownState               148
# F_startDate                 239
# F_endDate                   229
# E_startDate                 237
# E_endDate                   228
# C_startDate                 197
# C_endDate                   190
# G_startDate                 239
# G_endDate                   230
# A_startDate                 399
# A_endDate                   351
# brief                        20
# dtype: int64

# %% [markdown]
# #### Bộ train

# %% [markdown]
# Biến các kiểu categorical ở trên kiểu số học

# %%
train_labels = df_train["label"]
# Căn chỉnh dữ liệu trong hai bộ train và test. Giữ lại các cột có trong cả hai cột dữ liệu
df_train, df_test = df_train.align(df_train, join="inner", axis=1)
# Thêm mục "label"
df_train["label"] = train_labels

print("Bộ dữ liệu train: ", df_train.shape)
print("Bộ dữ liệu test: ", df_test.shape)
# Out:
# Bộ dữ liệu train:  (53030, 195)
# Bộ dữ liệu test:  (53030, 195)

# %% [markdown]
# Hiện tại ở hai bộ dữ liệu đều có những giá trị chung. Tuy nhiên số lượng còn nhiều, cần phải loại bỏ bớt

# %% [markdown]
# Điền dữ liệu còn thiếu bằng giá trị trung bình của mỗi cột

# %%
"Phân loại các cột dữ liệu theo kiểu"
numeric_cols = df_train.select_dtypes(['float', 'int']).columns
categoric_cols = df_train.select_dtypes('object').columns
train_numeric = df_train[numeric_cols]
train_categoric = df_train[categoric_cols]

# %%
# fill mising cho loại int và float
def fill_mean_train(train_numeric):
    for col in train_numeric.columns:
        mean = train_numeric[col].mean()
        train_numeric[col] = train_numeric[col].fillna(mean)
    return train_numeric
train_mean_imp = fill_mean_train(train_numeric)
# Out:
# C:\Users\Ut Luom\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#fill mising cho loại categoric sử dụng MODE
def fill_mode_train(train_categoric):
    for col in train_categoric.columns:
        mode = train_categoric[col].mode().iloc[0]
        train_categoric[col] = train_categoric[col].fillna(mode)
    return train_categoric
train_mode_imp = fill_mode_train(train_categoric)
# Out:
# C:\Users\Ut Luom\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
missing_numeric = missing_values(train_numeric)
# Out:
# Có tất cả 133 cột.
# Có tất cả 0 cột bị thiếu data

# %%
missing_categoric = missing_values(train_categoric)
# Out:
# Có tất cả 59 cột.
# Có tất cả 0 cột bị thiếu data

# %%
train_numeric.describe()
# Out:
#             Field_3      Field_10  Field_13  Field_14  Field_16  Field_17  \
# count  53030.000000  53030.000000   53030.0   53030.0   53030.0   53030.0
# mean       1.538687      1.096542       1.0       1.0       1.0       1.0
# std        0.346118      0.230921       0.0       0.0       0.0       0.0
# min        1.000000      0.000000       1.0       1.0       1.0       1.0
# 25%        1.538687      1.000000       1.0       1.0       1.0       1.0
# 50%        1.538687      1.096542       1.0       1.0       1.0       1.0
# 75%        2.000000      1.096542       1.0       1.0       1.0       1.0
# max        2.000000      5.000000       1.0       1.0       1.0       1.0
#
#            Field_19      Field_20      Field_21      Field_22  ...  \
# count  53030.000000  5.303000e+04  53030.000000  53030.000000  ...
# mean       0.267022  3.603181e+06      4.485331      0.999452  ...
# std        0.580415  1.584424e+06      0.195583      0.036846  ...
# min        0.000000  0.000000e+00      0.000000      0.000000  ...
# 25%        0.000000  3.603181e+06      4.485331      0.999452  ...
# 50%        0.267022  3.603181e+06      4.485331      0.999452  ...
# 75%        0.267022  3.777100e+06      4.500000      1.000000  ...
# max        6.864000  2.980000e+07      6.000000      2.000000  ...
#
#          partner5_F    partner5_G  partner5_H  partner5_K  partner5_L  \
# count  53030.000000  53030.000000     53030.0     53030.0     53030.0
# mean       0.000124      0.000041         0.0         0.0         0.0
# std        0.010636      0.006141         0.0         0.0         0.0
# min        0.000000      0.000000         0.0         0.0         0.0
# 25%        0.000000      0.000000         0.0         0.0         0.0
# 50%        0.000000      0.000000         0.0         0.0         0.0
# 75%        0.000000      0.000000         0.0         0.0         0.0
# max        1.000000      1.000000         0.0         0.0         0.0
#
#        num_of_phone      Field_78      Field_79      Field_80      Field_81
# count  53030.000000  53030.000000  53030.000000  53030.000000  53030.000000
# mean       1.087236     20.801440     30.911307     -1.793163    -32.149412
# std        0.290676     33.229363     26.033713     26.628262     52.258124
# min        1.000000   -267.000000      0.000000   -267.000000   -290.000000
# 25%        1.000000      9.000000     14.142136     -1.793163    -32.149412
# 50%        1.000000     20.801440     30.911307     -1.793163    -32.149412
# 75%        1.000000     25.000000     30.911307      5.250000      0.000000
# max        5.000000    242.000000    325.976226    238.000000    238.000000
#
# [8 rows x 133 columns]

# %% [markdown]
# #### Bộ test

# %%
"Phân loại các cột dữ liệu theo kiểu"
numeric_cols = df_test.select_dtypes(['float', 'int']).columns
categoric_cols = df_test.select_dtypes('object').columns
test_numeric = df_test[numeric_cols]
test_categoric = df_test[categoric_cols]

# %%
# fill mising cho loại int và float
def fill_mean_test(test_numeric):
    for col in test_numeric.columns:
        mean = test_numeric[col].mean()
        test_numeric[col] = test_numeric[col].fillna(mean)
    return test_numeric
test_mean_imp = fill_mean_test(test_numeric)
# Out:
# C:\Users\Ut Luom\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#fill mising cho loại categoric sử dụng MODE
def fill_mode_test(test_categoric):
    for col in test_categoric.columns:
        mode = test_categoric[col].mode().iloc[0]
        test_categoric[col] = test_categoric[col].fillna(mode)
    return test_categoric
test_mode_imp = fill_mode_test(test_categoric)
# Out:
# C:\Users\Ut Luom\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
missing_numeric = missing_values(test_numeric)
# Out:
# Có tất cả 133 cột.
# Có tất cả 0 cột bị thiếu data

# %%
missing_numeric = missing_values(test_categoric)
# Out:
# Có tất cả 59 cột.
# Có tất cả 0 cột bị thiếu data

# %% [markdown]
# ### Clean data

# %% [markdown]
# Train dataset

# %%
import sweetviz as sv

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class version: 0.0.68. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
#
# To remove previous versions, perform 'pip uninstall autoviz'

# %%
AV = AutoViz_Class()

# %%
train_numeric.columns
# Out:
# Index(['Field_3', 'Field_10', 'Field_13', 'Field_14', 'Field_16', 'Field_17',
#        'Field_19', 'Field_20', 'Field_21', 'Field_22',
#        ...
#        'partner5_F', 'partner5_G', 'partner5_H', 'partner5_K', 'partner5_L',
#        'num_of_phone', 'Field_78', 'Field_79', 'Field_80', 'Field_81'],
#       dtype='object', length=133)

# %%
train_numeric.describe()
# Out:
#             Field_3      Field_10  Field_13  Field_14  Field_16  Field_17  \
# count  53030.000000  53030.000000   53030.0   53030.0   53030.0   53030.0
# mean       1.538687      1.096542       1.0       1.0       1.0       1.0
# std        0.346118      0.230921       0.0       0.0       0.0       0.0
# min        1.000000      0.000000       1.0       1.0       1.0       1.0
# 25%        1.538687      1.000000       1.0       1.0       1.0       1.0
# 50%        1.538687      1.096542       1.0       1.0       1.0       1.0
# 75%        2.000000      1.096542       1.0       1.0       1.0       1.0
# max        2.000000      5.000000       1.0       1.0       1.0       1.0
#
#            Field_19      Field_20      Field_21      Field_22  ...  \
# count  53030.000000  5.303000e+04  53030.000000  53030.000000  ...
# mean       0.267022  3.603181e+06      4.485331      0.999452  ...
# std        0.580415  1.584424e+06      0.195583      0.036846  ...
# min        0.000000  0.000000e+00      0.000000      0.000000  ...
# 25%        0.000000  3.603181e+06      4.485331      0.999452  ...
# 50%        0.267022  3.603181e+06      4.485331      0.999452  ...
# 75%        0.267022  3.777100e+06      4.500000      1.000000  ...
# max        6.864000  2.980000e+07      6.000000      2.000000  ...
#
#          partner5_F    partner5_G  partner5_H  partner5_K  partner5_L  \
# count  53030.000000  53030.000000     53030.0     53030.0     53030.0
# mean       0.000124      0.000041         0.0         0.0         0.0
# std        0.010636      0.006141         0.0         0.0         0.0
# min        0.000000      0.000000         0.0         0.0         0.0
# 25%        0.000000      0.000000         0.0         0.0         0.0
# 50%        0.000000      0.000000         0.0         0.0         0.0
# 75%        0.000000      0.000000         0.0         0.0         0.0
# max        1.000000      1.000000         0.0         0.0         0.0
#
#        num_of_phone      Field_78      Field_79      Field_80      Field_81
# count  53030.000000  53030.000000  53030.000000  53030.000000  53030.000000
# mean       1.087236     20.801440     30.911307     -1.793163    -32.149412
# std        0.290676     33.229363     26.033713     26.628262     52.258124
# min        1.000000   -267.000000      0.000000   -267.000000   -290.000000
# 25%        1.000000      9.000000     14.142136     -1.793163    -32.149412
# 50%        1.000000     20.801440     30.911307     -1.793163    -32.149412
# 75%        1.000000     25.000000     30.911307      5.250000      0.000000
# max        5.000000    242.000000    325.976226    238.000000    238.000000
#
# [8 rows x 133 columns]

# %%
del train_numeric['partner3_C']

# %%
numeric = train_numeric.describe()
numeric
# Out:
#             Field_3      Field_10  Field_13  Field_14  Field_16  Field_17  \
# count  53030.000000  53030.000000   53030.0   53030.0   53030.0   53030.0
# mean       1.538687      1.096542       1.0       1.0       1.0       1.0
# std        0.346118      0.230921       0.0       0.0       0.0       0.0
# min        1.000000      0.000000       1.0       1.0       1.0       1.0
# 25%        1.538687      1.000000       1.0       1.0       1.0       1.0
# 50%        1.538687      1.096542       1.0       1.0       1.0       1.0
# 75%        2.000000      1.096542       1.0       1.0       1.0       1.0
# max        2.000000      5.000000       1.0       1.0       1.0       1.0
#
#            Field_19      Field_20      Field_21      Field_22  ...  \
# count  53030.000000  5.303000e+04  53030.000000  53030.000000  ...
# mean       0.267022  3.603181e+06      4.485331      0.999452  ...
# std        0.580415  1.584424e+06      0.195583      0.036846  ...
# min        0.000000  0.000000e+00      0.000000      0.000000  ...
# 25%        0.000000  3.603181e+06      4.485331      0.999452  ...
# 50%        0.267022  3.603181e+06      4.485331      0.999452  ...
# 75%        0.267022  3.777100e+06      4.500000      1.000000  ...
# max        6.864000  2.980000e+07      6.000000      2.000000  ...
#
#          partner5_F    partner5_G  partner5_H  partner5_K  partner5_L  \
# count  53030.000000  53030.000000     53030.0     53030.0     53030.0
# mean       0.000124      0.000041         0.0         0.0         0.0
# std        0.010636      0.006141         0.0         0.0         0.0
# min        0.000000      0.000000         0.0         0.0         0.0
# 25%        0.000000      0.000000         0.0         0.0         0.0
# 50%        0.000000      0.000000         0.0         0.0         0.0
# 75%        0.000000      0.000000         0.0         0.0         0.0
# max        1.000000      1.000000         0.0         0.0         0.0
#
#        num_of_phone      Field_78      Field_79      Field_80      Field_81
# count  53030.000000  53030.000000  53030.000000  53030.000000  53030.000000
# mean       1.087236     20.801440     30.911307     -1.793163    -32.149412
# std        0.290676     33.229363     26.033713     26.628262     52.258124
# min        1.000000   -267.000000      0.000000   -267.000000   -290.000000
# 25%        1.000000      9.000000     14.142136     -1.793163    -32.149412
# 50%        1.000000     20.801440     30.911307     -1.793163    -32.149412
# 75%        1.000000     25.000000     30.911307      5.250000      0.000000
# max        5.000000    242.000000    325.976226    238.000000    238.000000
#
# [8 rows x 132 columns]

# %%
numeric.columns
# Out:
# Index(['Field_3', 'Field_10', 'Field_13', 'Field_14', 'Field_16', 'Field_17',
#        'Field_19', 'Field_20', 'Field_21', 'Field_22',
#        ...
#        'partner5_F', 'partner5_G', 'partner5_H', 'partner5_K', 'partner5_L',
#        'num_of_phone', 'Field_78', 'Field_79', 'Field_80', 'Field_81'],
#       dtype='object', length=132)

# %%
advert_report = sv.analyze(numeric)
advert_report.show_html("Advertising_train_numeric.html")
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:28  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:02  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
categoric = train_categoric.describe()
categoric
# Out:
#                         Field_1                  Field_2 Field_4     Field_5  \
# count                     53030                    53030   53030       53030
# unique                    21506                    18667       2        1901
# top     2017-03-24T20:10:37.62Z  2017-03-24T20:10:37.62Z      T1  2018-12-27
# freq                      27730                    27727   41344       28586
#
#            Field_6     Field_7     Field_8     Field_9    Field_11 Field_12  \
# count        53030       53030       53030       53030       53030    53030
# unique        1870        1199        1392        1929         836        7
# top     2018-12-27  2019-01-01  2019-12-31  2018-12-27  2019-10-31       G8
# freq         28682       36280       38013       28538       46133    52728
#
#         ...   F_endDate E_startDate   E_endDate C_startDate   C_endDate  \
# count   ...       53030       53030       53030       53030       53030
# unique  ...         229         237         228         197         190
# top     ...  2019-08-18  2019-08-19  2019-08-19  2019-10-01  2019-12-12
# freq    ...       28585       28597       27780       31408       31374
#
#        G_startDate   G_endDate A_startDate   A_endDate  brief
# count        53030       53030       53030       53030  53030
# unique         239         230         399         351     20
# top     2019-10-01  2019-10-01  2019-09-04  2019-11-26      0
# freq         29640       29629       12050       12070  13956
#
# [4 rows x 59 columns]

# %% [markdown]
# Test dataset

# %%
test_numeric.columns
# Out:
# Index(['Field_3', 'Field_10', 'Field_13', 'Field_14', 'Field_16', 'Field_17',
#        'Field_19', 'Field_20', 'Field_21', 'Field_22',
#        ...
#        'partner5_F', 'partner5_G', 'partner5_H', 'partner5_K', 'partner5_L',
#        'num_of_phone', 'Field_78', 'Field_79', 'Field_80', 'Field_81'],
#       dtype='object', length=133)

# %%
numeric_test = test_numeric.describe()
numeric_test
# Out:
#             Field_3      Field_10  Field_13  Field_14  Field_16  Field_17  \
# count  53030.000000  53030.000000   53030.0   53030.0   53030.0   53030.0
# mean       1.538687      1.096542       1.0       1.0       1.0       1.0
# std        0.346118      0.230921       0.0       0.0       0.0       0.0
# min        1.000000      0.000000       1.0       1.0       1.0       1.0
# 25%        1.538687      1.000000       1.0       1.0       1.0       1.0
# 50%        1.538687      1.096542       1.0       1.0       1.0       1.0
# 75%        2.000000      1.096542       1.0       1.0       1.0       1.0
# max        2.000000      5.000000       1.0       1.0       1.0       1.0
#
#            Field_19      Field_20      Field_21      Field_22  ...  \
# count  53030.000000  5.303000e+04  53030.000000  53030.000000  ...
# mean       0.267022  3.603181e+06      4.485331      0.999452  ...
# std        0.580415  1.584424e+06      0.195583      0.036846  ...
# min        0.000000  0.000000e+00      0.000000      0.000000  ...
# 25%        0.000000  3.603181e+06      4.485331      0.999452  ...
# 50%        0.267022  3.603181e+06      4.485331      0.999452  ...
# 75%        0.267022  3.777100e+06      4.500000      1.000000  ...
# max        6.864000  2.980000e+07      6.000000      2.000000  ...
#
#          partner5_F    partner5_G  partner5_H  partner5_K  partner5_L  \
# count  53030.000000  53030.000000     53030.0     53030.0     53030.0
# mean       0.000124      0.000041         0.0         0.0         0.0
# std        0.010636      0.006141         0.0         0.0         0.0
# min        0.000000      0.000000         0.0         0.0         0.0
# 25%        0.000000      0.000000         0.0         0.0         0.0
# 50%        0.000000      0.000000         0.0         0.0         0.0
# 75%        0.000000      0.000000         0.0         0.0         0.0
# max        1.000000      1.000000         0.0         0.0         0.0
#
#        num_of_phone      Field_78      Field_79      Field_80      Field_81
# count  53030.000000  53030.000000  53030.000000  53030.000000  53030.000000
# mean       1.087236     20.801440     30.911307     -1.793163    -32.149412
# std        0.290676     33.229363     26.033713     26.628262     52.258124
# min        1.000000   -267.000000      0.000000   -267.000000   -290.000000
# 25%        1.000000      9.000000     14.142136     -1.793163    -32.149412
# 50%        1.000000     20.801440     30.911307     -1.793163    -32.149412
# 75%        1.000000     25.000000     30.911307      5.250000      0.000000
# max        5.000000    242.000000    325.976226    238.000000    238.000000
#
# [8 rows x 133 columns]

# %%
advert_report = sv.analyze(test_numeric)
advert_report.show_html("Advertising_test_numeric.html")
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:43  -> (00:00 left)
# :Processing Pairwise Features:     |▎                    | [  2%]   00:16  -> (17:41 left)

# %%
del test_numeric['partner5_F']

# %%
test_numeric.shape

# %%
train_numeric.shape

# %% [markdown]
# ### Histogram data

# %%
fig = plt.figure(figsize=(5, 3))
train_numeric["Field_19"].describe().plot.bar()
